# %%
import os
os.makedirs("Дополнительно", exist_ok=True)

# %%
import pandas as pd
import numpy as np
import os

# Создаю папку Дополнительно
os.makedirs("Дополнительно", exist_ok=True)

# Создаю df1
data = {
    "ID": [1,2,3,4,5],
    "Имя": ["Иван","Ольга","Алексей","Мария","Сергей"],
    "Возраст": [25,30,40,35,28],
    "Должность": ["Инженер","Аналитик","Менеджер","Программист","Специалист"],
    "Отдел": ["IT","Маркетинг","Продажи","IT","HR"],
    "Зарплата": [60000,75000,90000,80000,50000],
    "Стаж": [2,5,15,7,3]
}
df1 = pd.DataFrame(data)

# 2.1 CSV
df1.to_csv("Дополнительно/table1.csv", index=False, encoding="utf-8")
df_csv = pd.read_csv("Дополнительно/table1.csv")
print("CSV:")
print(df_csv.head())

# 2.2 Excel
df1.to_excel("Дополнительно/table1.xlsx", index=False)
df_excel = pd.read_excel("Дополнительно/table1.xlsx")
print("\nExcel:")
print(df_excel.head())

# 2.3 JSON
df1.to_json("Дополнительно/table1.json", orient="records", force_ascii=False)
df_json = pd.read_json("Дополнительно/table1.json")
print("\nJSON:")
print(df_json.head())
# Out:
# CSV:
#    ID      Имя  Возраст    Должность      Отдел  Зарплата  Стаж
# 0   1     Иван       25      Инженер         IT     60000     2
# 1   2    Ольга       30     Аналитик  Маркетинг     75000     5
# 2   3  Алексей       40     Менеджер    Продажи     90000    15
# 3   4    Мария       35  Программист         IT     80000     7
# 4   5   Сергей       28   Специалист         HR     50000     3
#
# Excel:
#    ID      Имя  Возраст    Должность      Отдел  Зарплата  Стаж
# 0   1     Иван       25      Инженер         IT     60000     2
# 1   2    Ольга       30     Аналитик  Маркетинг     75000     5
# 2   3  Алексей       40     Менеджер    Продажи     90000    15
# 3   4    Мария       35  Программист         IT     80000     7
# 4   5   Сергей       28   Специалист         HR     50000     3
#
# JSON:
#    ID      Имя  Возраст    Должность      Отдел  Зарплата  Стаж
# 0   1     Иван       25      Инженер         IT     60000     2
# ...
