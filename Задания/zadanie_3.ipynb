# %%
import pandas as pd

# %%
# Таблица 1 (сотрудники)
data = {
    "ID": [1,2,3,4,5],
    "Имя": ["Иван","Ольга","Алексей","Мария","Сергей"],
    "Возраст": [25,30,40,35,28],
    "Должность": ["Инженер","Аналитик","Менеджер","Программист","Специалист"],
    "Отдел": ["IT","Маркетинг","Продажи","IT","HR"],
    "Зарплата": [60000,75000,90000,80000,50000],
    "Стаж": [2,5,15,7,3]
}
df = pd.DataFrame(data)
df = df.set_index("ID")

# %%
# 3.1 .loc[] - сотрудник с ID=5
print("3.1 Сотрудник с ID=5:")
print(df.loc[5])
print()
# Out:
# 3.1 Сотрудник с ID=5:
# Имя              Сергей
# Возраст              28
# Должность    Специалист
# Отдел                HR
# Зарплата          50000
# Стаж                  3
# Name: 5, dtype: object

# %%
# 3.2 .iloc[] - возраст третьего сотрудника
print("3.2 Возраст третьего сотрудника:")
print(df.iloc[2, 2])
print()
# Out:
# 3.2 Возраст третьего сотрудника:
# Менеджер

# %%
# 3.3 .at[] - отдел Марии (ID=4)
print("3.3 Отдел Марии:")
print(df.at[4, "Отдел"])
print()
# Out:
# 3.3 Отдел Марии:
# IT

# %%
# 3.4 .iat[] - зарплата в 4-й строке, 5-м столбце
print("3.4 Зарплата в 4-й строке, 5-м столбце:")
print(df.iat[3, 5])
# Out:
# 3.4 Зарплата в 4-й строке, 5-м столбце:
# 7
