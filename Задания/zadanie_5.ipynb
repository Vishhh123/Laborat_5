# %%
# 5.1 Удалила столбец "Категория зарплаты"
df1 = df1.drop(columns=["Категория зарплаты"])
print("5.1 Столбцы после удаления:")
print(df1.columns)
print()
# Out:
# 5.1 Столбцы после удаления:
# Index(['ID', 'Имя', 'Возраст', 'Должность', 'Отдел', 'Зарплата', 'Стаж'], dtype='str')

# %%
# 5.2 Удалила строку с ID = 10
df1 = df1[df1["ID"] != 10]
print("5.2 После удаления ID=10:")
print(df1)
print()
# Out:
# 5.2 После удаления ID=10:
#    ID      Имя  Возраст    Должность      Отдел  Зарплата  Стаж
# 0   1     Иван       25      Инженер         IT     60000     2
# 1   2    Ольга       30     Аналитик  Маркетинг     75000     5
# 2   3  Алексей       40     Менеджер    Продажи     90000    15
# 3   4    Мария       35  Программист         IT     80000     7
# 4   5   Сергей       28   Специалист         HR     50000     3
# 5  21    Антон       32  Разработчик         IT     85000     6
# 6  22   Максим       29     Аналитик  Маркетинг     72000     4
# 7  23  Наталья       36     Менеджер    Продажи     92000    10

# %%
# 5.3 Удалила строки со стажем < 3 лет
df1 = df1[df1["Стаж"] >= 3]
print("5.3 После удаления стажа < 3:")
print(df1)
print()
# Out:
# 5.3 После удаления стажа < 3:
#    ID      Имя  Возраст    Должность      Отдел  Зарплата  Стаж
# 1   2    Ольга       30     Аналитик  Маркетинг     75000     5
# 2   3  Алексей       40     Менеджер    Продажи     90000    15
# 3   4    Мария       35  Программист         IT     80000     7
# 4   5   Сергей       28   Специалист         HR     50000     3
# 5  21    Антон       32  Разработчик         IT     85000     6
# 6  22   Максим       29     Аналитик  Маркетинг     72000     4
# 7  23  Наталья       36     Менеджер    Продажи     92000    10

# %%
# 5.4 Оставила только Имя, Должность, Зарплата
df1 = df1[["Имя", "Должность", "Зарплата"]]
print("5.4 Только Имя, Должность, Зарплата:")
print(df1)
# Out:
# 5.4 Только Имя, Должность, Зарплата:
#        Имя    Должность  Зарплата
# 1    Ольга     Аналитик     75000
# 2  Алексей     Менеджер     90000
# 3    Мария  Программист     80000
# 4   Сергей   Специалист     50000
# 5    Антон  Разработчик     85000
# 6   Максим     Аналитик     72000
# 7  Наталья     Менеджер     92000
