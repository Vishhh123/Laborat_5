# %%
import pandas as pd

s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
data = {
    "Возраст": [25, 30, 22],
    "Город": ["Москва", "СПб", "Казань"]
}

df = pd.DataFrame(data, index=["Анна", "Иван", "Ольга"])
print(df)
# Out:
#        Возраст   Город
# Анна        25  Москва
# Иван        30     СПб
# Ольга       22  Казань

# %%
print(df["Возраст"])
# Out:
# Анна     25
# Иван     30
# Ольга    22
# Name: Возраст, dtype: int64

# %%
s = pd.Series([10, 20, 30], index=["a", "b", "c"])
df = s.to_frame(name="Значение")
print(df)
# Out:
#    Значение
# a        10
# b        20
# c        30

# %%
s = df["Значение"]
print(s)
# Out:
# a    10
# b    20
# c    30
# Name: Значение, dtype: int64

# %%
import pandas as pd

data = {
    "Имя": ["Анна", "Иван", "Ольга"],
    "Возраст": [25, 30, 22],
    "Город": ["Москва", "СПб", "Казань"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
ages = pd.Series([25, 30, 22], index=["a", "b", "c"])
cities = pd.Series(["Москва", "СПб", "Казань"], index=["a", "b", "c"])

df = pd.DataFrame({"Возраст": ages, "Город": cities})
print(df)
# Out:
#    Возраст   Город
# a       25  Москва
# b       30     СПб
# c       22  Казань

# %%
data = [
    ["Анна", 25, "Москва"],
    ["Иван", 30, "СПб"],
    ["Ольга", 22, "Казань"]
]

df = pd.DataFrame(data, columns=["Имя", "Возраст", "Город"])
print(df)
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
numeric_data = np.array([
    [25, 65.5],
    [30, 78.2],
    [22, 54.3]
])

df = pd.DataFrame(numeric_data, columns=["Возраст", "Вес"])
print(df)
# Out:
#    Возраст   Вес
# 0     25.0  65.5
# 1     30.0  78.2
# 2     22.0  54.3

# %%
df = pd.DataFrame(columns=["Имя", "Возраст", "Город"])
print(df)
# Out:
# Empty DataFrame
# Columns: [Имя, Возраст, Город]
# Index: []

# %%
df.loc[0] = ["Анна", 25, "Москва"]
df.loc[1] = ["Иван", 30, "СПб"]
print(df)
# Out:
#     Имя  Возраст   Город
# 0  Анна       25  Москва
# 1  Иван       30     СПб

# %%
import pandas as pd

df = pd.read_csv("C:/Users/user/Laborat_5/Дополнительно/data.csv")
print(df.head())
# Out:
#      Имя  Возраст         Город
# 0   Анна       25        Москва
# 1   Иван       30           СПб
# 2  Ольга       22        Казань
# 3   Петр       40   Новосибирск
# 4  Мария       35  Екатеринбург

# %%
df = pd.read_csv("C:/Users/user/Laborat_5/Дополнительно/data.csv", sep=";", index_col=0, na_values=["?", "N/A"])
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: [Анна,25,Москва, Иван,30,СПб, Ольга,22,Казань, Петр,40,Новосибирск, Мария,35,Екатеринбург]

# %%
df.to_csv("C:/Users/user/Laborat_5/Дополнительно/output.csv", index=False)

# %%
df = pd.read_excel("C:/Users/user/Laborat_5/Дополнительно/data.xlsx", sheet_name="Лист1")
print(df.head())
# Out:
#      Имя  Возраст         Город
# 0   Анна       64        Москва
# 1   Иван       17           СПб
# 2  Ольга       12        Казань
# 3   Петр       33   Новосибирск
# 4  Мария       34  Екатеринбург

# %%
df.to_excel("C:/Users/user/Laborat_5/Дополнительно/output.xlsx", sheet_name="Результаты", index=False)

# %%
import sqlite3

conn = sqlite3.connect("Дополнительно/database.db")
query = "SELECT * FROM users"
df = pd.read_sql(query, conn)
print(df.head())
# Out:
#    id   name  age    city
# 0   1   Анна   25  Москва
# 1   2   Иван   30     СПб
# 2   3  Ольга   22  Казань

# %%
df = pd.read_json("C:/Users/user/Laborat_5/Дополнительно/dataa.json")
print(df.head())
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
df.to_json("Дополнительно/output.json", orient="records", indent=4)

# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

data = {
    "Имя": ["Анна", "Иван", "Ольга", "Петр", "Мария"],
    "Возраст": [25, 30, 22, 40, 35],
    "Город": ["Москва", "СПб", "Казань", "Новосибирск", "Екатеринбург"]
}

df = pd.DataFrame(data)
df.to_parquet("Дополнительно/data.parquet", engine="pyarrow", index=False)
print("Файл data.parquet создан!")
# Out:
# Файл data.parquet создан!

# %%
df.to_parquet("Дополнительно/output.parquet", engine="pyarrow", index=False)

# %%
import pandas as pd

data = {
    "Имя": ["Анна", "Иван", "Ольга", "Петр", "Мария", "Сергей"],
    "Возраст": [25, 30, 22, 40, 35, 28],
    "Город": ["Москва", "СПб", "Казань", "Новосибирск", "Екатеринбург", "Сочи"]
}

df = pd.DataFrame(data)

print(df.head(3))
# Out:
#      Имя  Возраст   Город
# 0   Анна       25  Москва
# 1   Иван       30     СПб
# 2  Ольга       22  Казань

# %%
print(df.tail(2))
# Out:
#       Имя  Возраст         Город
# 4   Мария       35  Екатеринбург
# 5  Сергей       28          Сочи

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Имя      6 non-null      str
#  1   Возраст  6 non-null      int64
#  2   Город    6 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 416.0 bytes

# %%
print(df.describe())
# Out:
#         Возраст
# count   6.00000
# mean   30.00000
# std     6.60303
# min    22.00000
# 25%    25.75000
# 50%    29.00000
# 75%    33.75000
# max    40.00000

# %%
print(df.describe(include="str"))
# Out:
#          Имя   Город
# count      6       6
# unique     6       6
# top     Анна  Москва
# freq       1       1

# %%
import pandas as pd

data = {
    "Имя": ["Анна", "Иван", "Ольга", "Петр"],
    "Возраст": [25, 30, 22, 40],
    "Город": ["Москва", "СПб", "Казань", "Новосибирск"]
}

df = pd.DataFrame(data, index=["a", "b", "c", "d"])
print(df)
# Out:
#      Имя  Возраст        Город
# a   Анна       25       Москва
# b   Иван       30          СПб
# c  Ольга       22       Казань
# d   Петр       40  Новосибирск

# %%
print(df.loc["b"])
# Out:
# Имя        Иван
# Возраст      30
# Город       СПб
# Name: b, dtype: object

# %%
print(df.loc[["a", "c"]])
# Out:
#      Имя  Возраст   Город
# a   Анна       25  Москва
# c  Ольга       22  Казань

# %%
print(df.loc[:, ["Имя", "Город"]])
# Out:
#      Имя        Город
# a   Анна       Москва
# b   Иван          СПб
# c  Ольга       Казань
# d   Петр  Новосибирск

# %%
print(df.loc[df["Возраст"] > 25])
# Out:
#     Имя  Возраст        Город
# b  Иван       30          СПб
# d  Петр       40  Новосибирск

# %%
print(df.iloc[1])
# Out:
# Имя        Иван
# Возраст      30
# Город       СПб
# Name: b, dtype: object

# %%
print(df.iloc[2, 2])
# Out:
# Казань

# %%
print(df.iloc[[0, 2]])
# Out:
#      Имя  Возраст   Город
# a   Анна       25  Москва
# c  Ольга       22  Казань

# %%
print(df.iloc[1:3])
# Out:
#      Имя  Возраст   Город
# b   Иван       30     СПб
# c  Ольга       22  Казань

# %%
print(df.iloc[:, [0, 2]])
# Out:
#      Имя        Город
# a   Анна       Москва
# b   Иван          СПб
# c  Ольга       Казань
# d   Петр  Новосибирск

# %%
print(df.at["c", "Город"])
# Out:
# Казань

# %%
print(df.iat[2, 2])
# Out:
# Казань
